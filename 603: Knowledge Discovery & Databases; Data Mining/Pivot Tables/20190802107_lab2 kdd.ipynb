# %% [markdown]
# # **KDD- Experiment 2**
#
# *    **SIA VASHIST**
# *    PRN: 20190802107
#
# ---

# %%
from IPython.display import Image
Image(filename='Capture.png')

# %% [markdown]
# # Operations performed:
# ><b>Total Sales by Country:</b>
# From the first pivot table operation, we can see which countries have the highest sales. This can help businesses focus on these countries to increase their revenue.
#
# ><b>Total Profit by Region:</b>
# From the second pivot table operation, we can see which regions are most profitable. Businesses can focus on these regions to increase their profits.
#
# ><b>Sales and Profit by City:</b>
# From the third pivot table operation, we can see which cities are most profitable and have the highest sales. This can help businesses focus on these cities to increase their revenue and profits.
#
# ><b>Sales by Customer and Region:</b>
# From the fourth pivot table operation, we can see which customers are buying the most in each region. This can help businesses target these customers with marketing and promotions.
#
# ><b>Average Profit by Country and Region:</b> From the fifth pivot table operation, we can see which countries and regions have the highest average profit. Businesses can focus on these areas to increase their profits
# ---

# %% [markdown]
# # Observations:
# >The highest sales and profits are coming from the US, followed by Canada and Australia.
#
# >Among the US cities, New York has the highest sales and profits, while in Canada, Toronto has the highest sales, and Manchester has the highest profits.
#
# >In Australia, Brisbane has the highest sales and profits, while in Saudi Arabia, Riyadh has the highest sales and profits.
#
# >When we group the countries by region, we can see that North America has the highest sales and profits, followed by Oceania and Western Asia.
#
# >Overall, we can conclude that the US is the most profitable country, and New York is the most profitable city. However, this dataset is limited and does not provide information on factors that could impact the profitability of each region, such as market size, competition, or economic conditions. Therefore, these conclusions should be taken with caution and validated with additional data and analysis.
